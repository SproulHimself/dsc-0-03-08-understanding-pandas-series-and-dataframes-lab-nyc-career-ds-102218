# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
df = df.rename(columns=(lambda x: x.lower()))
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
# df.columns = [x.lower() for x in df.columns]
# df

# %% [markdown]
# # Change the Index to be the Line Names

# %%
x = df.set_index(df.linename)
z = list(range(0, len(x)))

# %% [markdown]
# # Painstakingly change the index back

# %%
df.index = z

# %%
# df
# df.station

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
df['Num_Lines'] = df.linename.map(lambda x: len(x))
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# 3          7
# 4          7

# %% [markdown]
# ## Write a function to clean a column name.

# %%
df.rename({'two':'new_name'}, axis=1)

# %%
def clean(col_name):
    cleaned = col_name.title()
#     cleaned = df[col_name].title()
    #Your code here; whatever you want to do to col_name. Hint: think back to str methods.
    return cleaned
clean('unit')
# Out:
# 'Unit'

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
df.head()
# Out:
#     C/A  Unit       Scp Station Linename Division        Date      Time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       Desc  Entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    Exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    Num_Lines
# 0          7
# 1          7
# 2          7
# 3          7
# 4          7

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['C/A', 'Unit', 'Scp', 'Station', 'Linename', 'Division', 'Date', 'Time',
#        'Desc', 'Entries',
#        'Exits                                                               ',
#        'Num_Lines'],
#       dtype='object')

# %%
# df.groupby('Station').mean()

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
# da = df.groupby('Station')

# %%
df['Date'] = pd.to_datetime(df.Date)

# %%
df['Dayofweek'] = df.Date.dt.dayofweek

# %%
grouped = df.groupby('Dayofweek').sum()
# grouped

# %%
grouped.plot(kind='barh')

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %% [raw]
# grouped

# %%
df3 = grouped.iloc[0:5].sum()
df3
# Out:
# Entries                                                                 5614154250681
# Exits                                                                   4602290732124
# Num_Lines                                                                      381306
# dtype: int64

# %%
df4 = grouped.iloc[5:].sum()
df4
# Out:
# Entries                                                                 2307967724596
# Exits                                                                   1868365831935
# Num_Lines                                                                      150031
# dtype: int64

# %%
df3/5
# Out:
# Entries                                                                 1.122831e+12
# Exits                                                                   9.204581e+11
# Num_Lines                                                               7.626120e+04
# dtype: float64

# %%
df4/2
# Out:
# Entries                                                                 1.153984e+12
# Exits                                                                   9.341829e+11
# Num_Lines                                                               7.501550e+04
# 197610  RIT-ROOSEVELT        R      RIT 2018-08-29  13:00:00     5554
# 197611  RIT-ROOSEVELT        R      RIT 2018-08-29  17:00:00     5554
# 197612  RIT-ROOSEVELT        R      RIT 2018-08-29  21:00:00     5554
# 197613  RIT-ROOSEVELT        R      RIT 2018-08-30  01:00:00     5554
# 197614  RIT-ROOSEVELT        R      RIT 2018-08-30  05:00:00     5554
# 197615  RIT-ROOSEVELT        R      RIT 2018-08-30  09:00:00     5554
# 197616  RIT-ROOSEVELT        R      RIT 2018-08-30  13:00:00     5554
# 197617  RIT-ROOSEVELT        R      RIT 2018-08-30  17:00:00     5554
# 197618  RIT-ROOSEVELT        R      RIT 2018-08-30  21:00:00     5554
# 197619  RIT-ROOSEVELT        R      RIT 2018-08-31  01:00:00     5554
# 197620  RIT-ROOSEVELT        R      RIT 2018-08-31  05:00:00     5554
# 197621  RIT-ROOSEVELT        R      RIT 2018-08-31  09:00:00     5554
# 197622  RIT-ROOSEVELT        R      RIT 2018-08-31  13:00:00     5554
# 197623  RIT-ROOSEVELT        R      RIT 2018-08-31  17:00:00     5554
# 197624  RIT-ROOSEVELT        R      RIT 2018-08-31  21:00:00     5554
#
#         Exits                                                                 \
# 0                                                 2283184
# 1                                                 2283188
# 2                                                 2283229
# 3                                                 2283314
# 4                                                 2283384
# 5                                                 2283425
# 6                                                 2283460
# 7                                                 2283461
# 8                                                 2283483
# 9                                                 2283524
# 10                                                2283587
# 11                                                2283631
# 12                                                2283656
# 13                                                2283658
# 14                                                2283736
# 15                                                2283965
# 16                                                2284025
# 17                                                2284091
# 18                                                2284121
# 19                                                2284126
# 20                                                2284216
# 21                                                2284402
# 22                                                2284425
# 23                                                2284478
# 24                                                2284508
# 25                                                2284512
# 26                                                2284600
# 27                                                2284838
# 28                                                2284896
# 29                                                2284941
# ...                                                   ...
# 197595                                                348
# 197596                                                348
# 197597                                                348
# 197598                                                348
# 197599                                                348
# 197600                                                348
# 197601                                                348
# 197602                                                348
# 197603                                                348
# 197604                                                348
# 197605                                                348
# 197606                                                348
# 197607                                                348
# 197608                                                348
# 197609                                                348
# 197610                                                348
# 197611                                                348
# 197612                                                348
# 197613                                                348
# 197614                                                348
# 197615                                                348
# 197616                                                348
# 197617                                                348
# 197618                                                348
# 197619                                                348
# 197620                                                348
# 197621                                                348
# 197622                                                348
# 197623                                                348
# 197624                                                348
#
#         Num_Lines  Dayofweek
# 0               7          5
# 1               7          5
# 2               7          5
# 3               7          5
# 4               7          5
# 5               7          5
# 6               7          6
# 7               7          6
# 8               7          6
# 9               7          6
# 10              7          6
# 11              7          6
# 12              7          0
# 13              7          0
# 14              7          0
# 15              7          0
# 16              7          0
# 17              7          0
# 18              7          1
# 19              7          1
# 20              7          1
# 21              7          1
# 22              7          1
# 23              7          1
# 24              7          2
# 25              7          2
# 26              7          2
# 27              7          2
# 28              7          2
# 29              7          2
# ...           ...        ...
# 197595          1          0
# 197596          1          0
# 197597          1          0
# 197598          1          0
# 197599          1          0
# 197600          1          0
# 197601          1          1
# 197602          1          1
# 197603          1          1
# 197604          1          1
# 197605          1          1
# 197606          1          1
# 197607          1          2
# 197608          1          2
# 197609          1          2
# 197610          1          2
# 197611          1          2
# 197612          1          2
# 197613          1          3
# 197614          1          3
# 197615          1          3
# 197616          1          3
# 197617          1          3
# 197618          1          3
# 197619          1          4
# 197620          1          4
# 197621          1          4
# 197622          1          4
# 197623          1          4
# 197624          1          4
#
# [197625 rows x 9 columns]
